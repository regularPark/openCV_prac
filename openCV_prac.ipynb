# %%
import cv2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
image = cv2.imread('/content/drive/MyDrive/openCV/people.png')

# %%
image.shape
# Out:
# (600, 800, 3)

# %%
#cv2.imshow(image)
from google.colab.patches import cv2_imshow
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7F67B5A7DDD0>

# %%
image = cv2.resize(image, (640, 480))
cv2_imshow(image)
# Out:
# <PIL.Image.Image image mode=RGB size=640x480 at 0x7F67B5A7D590>

# %%
image_gray = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
cv2_imshow(image_gray)
# Out:
# <PIL.Image.Image image mode=L size=640x480 at 0x7F67B5942C10>

# %%
image.shape
image_gray.shape
# Out:
# (480, 640)
